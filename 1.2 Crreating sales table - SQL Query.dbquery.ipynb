-- %%
CREATE OR REPLACE TABLE ecommerce.retail_customer.sales_bronze 
AS 
SELECT * FROM databricks_simulated_retail_customer_data.v01.sales;

select * from ecommerce.retail_customer.orders_bronze;
select * from ecommerce.retail_customer.sales_bronze;
