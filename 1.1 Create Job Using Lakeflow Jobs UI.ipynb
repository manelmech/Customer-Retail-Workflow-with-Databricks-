# %%
sales_orders = spark.read.table("databricks_simulated_retail_customer_data.v01.sales_orders")

# %%
sales_orders.display()

# %%
# %sql
use catalog ecommerce;
use schema retail_customer;

# %%
sales_orders.write.mode("overwrite").saveAsTable("orders_bronze")
