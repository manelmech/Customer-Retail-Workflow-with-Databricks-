# %%
customerSalesDf= spark.read.table("ecommerce.retail_customer.customers_sales_silver")

# %%
customerSalesDeduplicated = customerSalesDf.dropDuplicates()

# %%
customerSalesDeduplicated.write.mode("overwrite").saveAsTable("ecommerce.retail_customer.customers_sales_silver")
